# %%
a=10
b=20
c=a+b
print(c)
print('welcomee')
# Out:
# 30
# welcomee

# %%
for i in range(10):
    pass

# %%
import time
time.sleep(5)
print("Hiiiii")
# Out:
# Hiiiii

# %%
a=1000
print(a)

# %%
import os
# cwd means current work directoey.
os.getcwd()

# %%
NUMBER=100
NUMBER
# Out:
# 100

# %%
number=200
number
# Out:
# 200

# %%
NUMBER,number
# Out:
# (100, 200)

# %%
NUMber=400
NUMber
# Out:
# 400

# %%
numBER=500
numBER
# Out:
# 500

# %%
number123=600
number123
# Out:
# 600

# %%
123number=2332
123number           #Numbers in the starting not allowed.
# Out:
#   Cell In[7], line 1
#     123number=2332
#       ^
# SyntaxError: invalid decimal literal

# %%
num@ber=233
num@ber           #Special characters are not allowed.
# Out:
#   Cell In[8], line 1
#     num@ber=233
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
$num=200
$num
# Out:
#   Cell In[9], line 1
#     $num=200
#     ^
# SyntaxError: invalid syntax

# %%
num_one=123
num_one
# Out:
# 123

# %%
areaofcircle=233
areaofcircle
# Out:
# 233

# %%
area_of_circle=444
area_of_circle
# Out:
# 444

# %%
area of circle=555
area of circle    #spacer are like special characters insted of spaces we use underscores.
# Out:
#   Cell In[13], line 1
#     area of circle=555
#          ^
# SyntaxError: invalid syntax

# %%
_=12
_
# Out:
# 12

# %%
_num=33
_num
# Out:
# 33

# %%
sum=444
sum
# Out:
# 444

# %%
l=[1,2,3,4]

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
type(l)
# Out:
# list

# %%
max(l)
# Out:
# 4

# %%
min(l)
# Out:
# 1

# %%
len(l)
# Out:
# 4

# %%
sum(l)
# Out:
# 10

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l=[1,2,3,4]
sum(l)
# Out:
# 10

# %% [markdown]
# Variables can be capital letters and small letters.
#
# Variables are case sensitive.
#
# Variables does not allow special characters.
#
# Numbers as prefix are not allowed(ex:123number=222).
#
# Variables can use underscores( _ ).
#
# Only underscore also possible.
#
# Reserved words and Keywords cannot be a variables.
#
# inbuilt functions cannot use as a variable

# %%
# write a program take 3 variables a,b,c
# provide the values
# find the average

a=100
b=200
c=300
average=(a+b+c)/3
average
# Out:
# 200.0

# %%
# wap calculate area of circle
# pi=3.14 r
# formula= pi*r*r

pi = 3.14
r = 3
area_of_circle=pi*r*r
area_of_circle
# Out:
# 28.259999999999998

# %%
# wap ask the user
# take bill amount and tip amount.
# calculate total bill
# total bill = bill amount + tip amount

# bill_amount=int(input())
# tip_amount=int(input())
bill_amount=200
tip_amount=50
total_bill=bill_amount+tip_amount
total_bill
# Out:
# 250

# %%
# wap ask user take the weight value and convert into pounds
# formuls: pound=weight*2.2

# weight_value=float(input())
weight_value=55.50
pound=weight_value*2.2
pound
# Out:
# 122.10000000000001

# %%
# wap ask the user money in dollar and convert it into indian currency
# indian rupee= 80*dollars

# dollars=int(input())
dollars=50
indian_currency=80*dollars
indian_currency
# Out:
# 4000
