# %% [markdown]
# - print is a inbuilt statement to print outputs.
# - We always work towards only one end goal: **Customer satisfaction**
# - Clint doesn't know the python code.
# - What ever we want to show the output we need to show it very clearly.

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')   # it will print as it is coz it is in between quotes.
# Out:
# the addition of 100 and 200 is 300

# %% [markdown]
# - if we change the n1 and n2 variables it will not automatically updates so we need to write in a way. that it should automatically update the values at print statement.
#     - two types

# %%
print('hii')
print('hello','hii')
print('hii','hello',n1)
# Out:
# hii
# hello hii
# hii hello 1000

# %%
# 1st method
n1=1000
n2=2000
add=n1+n2
print('the addition of', 100, 'and', 200, 'is 300')
# Out:
# the addition of 100 and 200 is 300

# %%
Name='Vikki'
age=22
place='Erragadda'
print('Im', Name, age, 'years old coming from', place)
# Out:
# Im Vikki 22 years old coming from Erragadda

# %% [markdown]
# **format() method**

# %%
# 2nd method
n1=1000
n2=2000
add=n1+n2
print('the addition of 100 and 200 is 300')
print('the addition of {} and {} is {}')
print('the addition of {} and {} is {}'.format(n1,n2,add))   # this is a format method where we give variables to the format function.
# Out:
# the addition of 100 and 200 is 300
# the addition of {} and {} is {}
# the addition of 1000 and 2000 is 3000

# %%
Name='Vikki'
age=22
place='Erragadda'
print('Im {} {} years old coming from {}'.format(Name,age,place))
# Out:
# Im Vikki 22 years old coming from Erragadda

# %% [markdown]
# **f-string**
# - it is the easiest method to write variables in between string in print statement.

# %%
n1=1000
n2=2000
add=n1+n2
print(f'the addition of {n1} and {n2} is {add}')
# Out:
# the addition of 1000 and 2000 is 3000

# %%
Name='Vikki'
age=22
place='Erragadda'
print(f'Im {Name} {age} years old coming from {place}')
# Out:
# Im Vikki 22 years old coming from Erragadda

# %%
# question 1
num1=10
num2=20
sub=num1-num2
mul=num1*num2
div=num1/num2
print(f'the subtraction of {num1} and {num2} is {sub}')
print(f'the multiplication of {num1} and {num2} is {mul}')
print(f'the division of {num1} and {num2} is {div}')
print('the subtraction of {} and {} is {}'.format(num1,num2,sub))
print('the multiplication of {} and {} is {}'.format(num1,num2,mul))
print('the division of {} and {} is {}'.format(num1,num2,div))
# Out:
# the subtraction of 10 and 20 is -10
# the multiplication of 10 and 20 is 200
# the division of 10 and 20 is 0.5

# %%
# question 2
r=15
pi=3.14
area_of_circle=pi*r*r
print(f'the area of circle is: {area_of_circle}')
print('the area of circle is: {}'.format(area_of_circle))
# Out:
# the area of circle is: 706.5
# the area of circle is: 706.5

# %%
# question 3
height=10
breadth=20
area_of_triangle=0.5*breadth*height
print(f'the area of triangle is: {area_of_triangle}')
print('the area of triangle is: {}'.format(area_of_triangle))
# Out:
# the area of triangle is: 100.0
# the area of triangle is: 100.0

# %%
# question 4
a=100
b=200
c=300
average=(a+b+c)/3
print('the average of {},{},{} is {}'.format(a,b,c,average))
print(f'the average of {a},{b},{c} is {average}')
# Out:
# the average of 100,200,300 is 200.0
# the average of 100,200,300 is 200.0

# %%
# question 5
bill_amount=200
tip_amount=50
total_bill=bill_amount+tip_amount
print('the total bill is {}'.format(total_bill))
print(f'the total bill is {total_bill}')
# Out:
# the total bill is 250
# the total bill is 250

# %%
# question 6
salary=300000
tax_percentage=10
tax_amount=salary*tax_percentage/100
print('the tax amount of salary {} with percentage of {} is{}'.format(sal))
