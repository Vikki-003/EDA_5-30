# %% [markdown]
# **try-except**
#
# - try except is used to handel the exception mechanism
# - try except is used to handel and catch the errors
# - When we get the error python will stop execution
# - using try except eventhrough we get the errors, the execution will not stop
# - it will catch all the logical errors automatically
# - the actual code block will write in **try block**
# - if any error occur in try block, will caght the error in **except block**
# - syntax errors will not catch

# %%
print(1+'')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(1+'')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **AttributeError**

# %%
import math
math.vikki
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 import math
# ----> 2 math.vikki
#
# AttributeError: module 'math' has no attribute 'vikki'

# %% [markdown]
# **ZeroDivisionError**

# %%
100/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 100/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **module not found**

# %%
import vik
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import vik
#
# ModuleNotFoundError: No module named 'vik'

# %% [markdown]
# **value error**

# %%
int('10.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
- value error
- type error
- name error
- zero division error
- module not found
- attribute error
- file exist error

# %%
import os
os.makedirs('vikki')

# %%
os.makedirs('vikki')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 os.makedirs('vikki')
#
# File ~\anaconda3\Lib\os.py:228, in makedirs(name, mode, exist_ok)
#     226         return
#     227 try:
# --> 228     mkdir(name, mode)
#     229 except OSError:
#     230     # Cannot rely on checking for EEXIST, since the operating system
#     231     # could give priority to other errors like EACCES or EROFS
#     232     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'vikki'

# %%
# syntax
try:
    <original code>
except Exception as e:
    print(e)

# %%
try:
    int('10.5')
except Exception as e:
    print(e)
    print('you are wrong')
# Out:
# invalid literal for int() with base 10: '10.5'
# you are wrong

# %%
try:
    a=int(10.5)
    print(a)
except Exception as e:
    print(e)
# Out:
# 10

# %%
try:
    print('hello')
    print('hii')
    int('10.5')
except Exception as vikki:
    print(vikki)
    print('you are weong')
# Out:
# hello
# hii
# invalid literal for int() with base 10: '10.5'
# you are weong

# %%
try:
    import os
    os.makedirs('vikki')
except Exception as e:
    print(e)
    print('file already exist')
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'vikki'
# file already exist

# %%
try:
    import os
    os.makedirs('vikki')
except Exception as e:
    print('try another file name')
    print('file already exist')
# Out:
# try another file name
# file already exist

# %%
# type error
try:
    print(1+'hii')
except Exception as e:
    print(e)
    print('change either number as string or remove string')
# Out:
# unsupported operand type(s) for +: 'int' and 'str'
# change either number as string or remove string

# %%
# name error
try:
    print(variable)
except Exception as e:
    print(e)
    print('give a proper variable')
# Out:
# name 'variable' is not defined
# give a proper variable

# %%
# zero division error

try:
    a=10/0
    print(a)
except Exception as e:
    print(e)
    print('use another number in denimenator')
# Out:
# division by zero
# use another number in denimenator

# %%
# module not found
try:
    import vicky
except Exception as e:
    print(e)
    print('give a proper module name')
# Out:
# No module named 'vicky'
# give a proper module name

# %%
# attribute not found
try:
    import random
    random.vikki()
except Exception as e:
    print(e)
    print('give the correct attribute from the module')
# Out:
# module 'random' has no attribute 'vikki'
# give the correct attribute from the module

# %%
try:
    print('hii')
      print('hello')
except Exception as e:
    print(e)
    print('intend')
# Out:
#   Cell In[30], line 3
#     print('hello')
#     ^
# IndentationError: unexpected indent

# %%
try:
    salary=eval(input('enter the salary:'))
    tax_per=eval(input('enter tax per:'))
    tax=salary*tax_per/100
    print(f'the tax is: {tax}')
except Exception as e:
    print(e)
# Out:
# enter the salary: 500000
# enter tax per: 25
# the tax is: 125000.0

# %%
try:
    num=eval(input('enter num:'))
    if num%2==0:
        print(f'{num} is even')
    else:
        print(f'{num} is odd')
except Exception as e:
    print(e)
# Out:
# enter num: -11
# -11 is odd

# %% [markdown]
# **try-except-finally**
# - original code in **try** block
# - error catch in **except** block
# - **finally** block will activate either or try and except activate
# - assume that try block executed then finally block can also execute
# - assume that except block executed then also finally block executed

# %%
try:
    print('connection established')
except Exception as e:
    print(e)
finally:
    print('connection closed')
# Out:
# connection established
# connection closed
